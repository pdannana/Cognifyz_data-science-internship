# %% [markdown]
# <a href="https://colab.research.google.com/github/pdannana/Cognifyz_data-science-internship/blob/main/task1_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Upload the dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b6200060-4bca-459b-a3b5-31fb027ef28f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6200060-4bca-459b-a3b5-31fb027ef28f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the dataset (assuming the uploaded file is named 'Dataset .csv')
df = pd.read_csv(list(uploaded.keys())[0])

# Display the number of rows and columns
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# The dataset has 9551 rows and 21 columns.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Handle missing values (e.g., fill with mean or drop them)
df.fillna(df.mean(), inplace=True)  # Example: Filling missing values with column mean

# Verify if missing values are handled
missing_values_after = df.isnull().sum()
print("Missing values after handling:\n", missing_values_after)
# Out:
# Missing values in each column:
#  Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-479b77aefca9> in <cell line: 6>()
#       4
#       5 # Handle missing values (e.g., fill with mean or drop them)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Step 1: Upload the dataset
uploaded = files.upload()

# Step 2: Load the dataset (assuming the uploaded file is named 'Dataset .csv')
df = pd.read_csv(list(uploaded.keys())[0])

# Display the number of rows and columns
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns.')

# Step 3: Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Handle missing values for numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Handle missing values for non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns
for col in non_numeric_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify if missing values are handled
missing_values_after = df.isnull().sum()
print("Missing values after handling:\n", missing_values_after)

# Step 4: Check data types of each column
print("Data types of each column:\n", df.dtypes)

# Perform data type conversion if necessary (example: converting a column to integer)
# df['column_name'] = df['column_name'].astype('int')

# Step 5: Analyze the distribution of the target variable
sns.histplot(df['Aggregate rating'], kde=True)
plt.title('Distribution of Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# Identify class imbalances
class_counts = df['Aggregate rating'].value_counts()
print("Class distribution of Aggregate Rating:\n", class_counts)

# Visualize class imbalance
sns.countplot(x='Aggregate rating', data=df)
plt.title('Class Distribution of Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Count')
plt.show()
# Out:
#      <input type="file" id="files-6ca548d6-aa20-407e-a50d-053896f8ce52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ca548d6-aa20-407e-a50d-053896f8ce52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload the file
uploaded = files.upload()

# Read the file into a DataFrame
file_name = list(uploaded.keys())[0]
data = pd.read_csv(file_name)

# Display the first few rows of the DataFrame
data.head()
# Out:
#      <input type="file" id="files-39434e77-35a8-40ac-b42b-e6cbd6b709ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39434e77-35a8-40ac-b42b-e6cbd6b709ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Calculate basic statistical measures for numerical columns
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
numerical_stats = data[numerical_columns].describe()

numerical_stats
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Select numerical columns
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

# Calculate basic statistical measures
basic_stats = data[numerical_columns].agg(['mean', 'median', 'std', 'min', 'max'])

basic_stats
# Out:
#         Restaurant ID  Country Code   Longitude   Latitude  \
# mean     9.051128e+06     18.365616   64.126574  25.854381
# median   6.004089e+06      1.000000   77.191964  28.570469
# std      8.791521e+06     56.750546   41.467058  11.007935
# min      5.300000e+01      1.000000 -157.948486 -41.330428
# max      1.850065e+07    216.000000  174.832089  55.976980
#
#         Average Cost for two  Price range  Aggregate rating         Votes
# mean             1199.210763     1.804837          2.666370    156.909748
# median            400.000000     2.000000          3.200000     31.000000
# std             16121.183073     0.905609          1.516378    430.169145
# min                 0.000000     1.000000          0.000000      0.000000
# max            800000.000000     4.000000          4.900000  10934.000000
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Upload the dataset
uploaded = files.upload()

# Load the dataset into a pandas DataFrame
file_name = list(uploaded.keys())[0]
data = pd.read_csv(file_name)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())

# Display basic information about the dataset
print("\nDataset information:")
print(data.info())

# Display summary statistics of the dataset
print("\nSummary statistics:")
print(data.describe())

# Distribution analysis of categorical variables
# Country Code distribution
print("\nCountry Code distribution:")
print(data['Country Code'].value_counts())

# City distribution
print("\nCity distribution:")
print(data['City'].value_counts())

# Cuisines distribution
print("\nCuisines distribution:")
print(data['Cuisines'].value_counts())

# Identify the top cuisines
top_cuisines = data['Cuisines'].value_counts().head(10)
print("\nTop 10 Cuisines:")
print(top_cuisines)

# Identify the top cities with the highest number of restaurants
top_cities = data['City'].value_counts().head(10)
print("\nTop 10 Cities with the highest number of restaurants:")
print(top_cities)

# Plot the top cuisines
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cuisines.values, y=top_cuisines.index, palette='viridis')
plt.title('Top 10 Cuisines')
plt.xlabel('Number of Restaurants')
plt.ylabel('Cuisines')
plt.show()

# Plot the top cities with the highest number of restaurants
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cities.values, y=top_cities.index, palette='viridis')
plt.title('Top 10 Cities with the Highest Number of Restaurants')
plt.xlabel('Number of Restaurants')
plt.ylabel('Cities')
plt.show()
# Out:
#      <input type="file" id="files-a0b24a9f-d54b-46ae-958e-ff10f502e733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0b24a9f-d54b-46ae-958e-ff10f502e733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
